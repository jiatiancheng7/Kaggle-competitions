# %%
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.model_selection import train_test_split 
from sklearn.neighbors import KNeighborsClassifier
import numpy as np
import pandas as pd
iris_data = datasets.load_iris()
X = iris_data.data
Y = iris_data.target

SSE=[]
X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size=0.3,random_state=21)

## UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator.

for i in range(1,101,1):
  model = KNeighborsClassifier(n_neighbors=i)  
  model.fit(X_train,y_train)
  SSE.append(model.score(X_test,y_test))
print(SSE)


plt.plot(range(1,101,1), SSE)
plt.show()
# Out:
# [0.9555555555555556, 0.9333333333333333, 0.9333333333333333, 0.9333333333333333, 0.9333333333333333, 0.9111111111111111, 0.8888888888888888, 0.8888888888888888, 0.8888888888888888, 0.8888888888888888, 0.9111111111111111, 0.8666666666666667, 0.8666666666666667, 0.8444444444444444, 0.8666666666666667, 0.8444444444444444, 0.8666666666666667, 0.8666666666666667, 0.8666666666666667, 0.8666666666666667, 0.8888888888888888, 0.8888888888888888, 0.8888888888888888, 0.8888888888888888, 0.8888888888888888, 0.9111111111111111, 0.9333333333333333, 0.9111111111111111, 0.9333333333333333, 0.9111111111111111, 0.9333333333333333, 0.9111111111111111, 0.9333333333333333, 0.9111111111111111, 0.9111111111111111, 0.8888888888888888, 0.9111111111111111, 0.8888888888888888, 0.8888888888888888, 0.8666666666666667, 0.8888888888888888, 0.8444444444444444, 0.8666666666666667, 0.8, 0.8666666666666667, 0.8222222222222222, 0.8222222222222222, 0.8222222222222222, 0.8222222222222222, 0.8, 0.8, 0.7777777777777778, 0.7777777777777778, 0.7777777777777778, 0.8, 0.7777777777777778, 0.7777777777777778, 0.7777777777777778, 0.7777777777777778, 0.7777777777777778, 0.8, 0.7777777777777778, 0.8222222222222222, 0.8222222222222222, 0.8444444444444444, 0.7777777777777778, 0.8222222222222222, 0.7777777777777778, 0.8222222222222222, 0.8, 0.8, 0.8, 0.8, 0.8, 0.7777777777777778, 0.7777777777777778, 0.7777777777777778, 0.7777777777777778, 0.7777777777777778, 0.7777777777777778, 0.7777777777777778, 0.7777777777777778, 0.7777777777777778, 0.7777777777777778, 0.7777777777777778, 0.7777777777777778, 0.7555555555555555, 0.7555555555555555, 0.7555555555555555, 0.7555555555555555, 0.7555555555555555, 0.7555555555555555, 0.7555555555555555, 0.7555555555555555, 0.7333333333333333, 0.7333333333333333, 0.7333333333333333, 0.7333333333333333, 0.7333333333333333, 0.6888888888888889]
